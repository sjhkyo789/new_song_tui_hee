# %% [markdown]
# # 🌼 기초 프로그래밍 및 데이터 구조 - 2차시
#
# ---

# %% [markdown]
# ## 1. 파이썬 자료형
#
# 파이썬에서 자주 사용되는 자료형:
#
# - `정수형(Integer)`
# 정수를 나타내는 자료형 (int)
#
# - `실수형(Float)`
# 실수를 나타내는 자료형 (float)
#
# - `문자열(String)`
# 문자를 나타내는 자료형 (str)
#
# - `불형(Boolean)`
# 참(True)과 거짓(False)을 나타내는 자료형 (bool)

# %% [markdown]
# ## 2. 정수형과 실수형
#
# 정수형(`int`)과 실수형(`float`)은 숫자를 표현하는 자료형.
# - 정수형은 소수점이 없는 숫자를, 실수형은 소수점이 있는 숫자를 나타냄

# %%
a = 10
b = 3.141592
c = 100.0
d = -3
e = -8.5

# %% [markdown]
# ### 정수와 실수 간 형변환

# %%
str(5)
# Out:
# '5'

# %% [markdown]
# ## 3. 문자열(String)
#
# 문자열(`str`)은 문자의 집합
# 문자열은 작은따옴표(' ') 또는 큰따옴표(" ")로 묶어 표현할 수 있음

# %% [markdown]
# ### 연결

# %% [markdown]
# ### 반복

# %% [markdown]
# ### 인덱싱

# %%
a='apple'

b = a.upper()

# %% [markdown]
# ### 슬라이싱

# %%
d = 'text'
d.replace ('x','s')
# Out:
# 'test'

# %%
b = a[0:3]

# %% [markdown]
# ### 이스케이프 코드

# %% [markdown]
# ### 길이 구하기

# %% [markdown]
# ### 그 외 문자열의 내장함수
# 1. upper(), lower()
# 2. strip()
# 3. replace()
# 4. split()

# %% [markdown]
#  Q1. 주어진 문자열을 모두 대문자로 변환해 출력해보세요

# %%
sent = 'i love python'
sent.upper()
# Out:
# 'I LOVE PYTHON'

# %% [markdown]
# Q2. 문장에서 apple을 peach로 바꿔보세요

# %%
sent = 'I love apple'
sent.replace('apple','peach')
# Out:
# 'I love peach'

# %% [markdown]
# Q3. 문장에서 공백을 언더바(_)로 바꿔보세요

# %%
sent = 'Fill in the gaps in this sentence'
sent.replace(' ','_')
# Out:
# 'Fill_in_the_gaps_in_this_sentence'

# %% [markdown]
# ### 문자열 포매팅
# - % 연산자 포매팅

# %%
weather = '맑음'
temp = 27

# %% [markdown]
# Q1. 섭씨 온도를 입력받아, 해당 온도를 화씨로 변환한 값을 출력하세요.
#
# 섭씨(C)를 화씨(F)로 변환하는 공식은 F = C * 9/5 + 32입니다.
#
# 문자열 포매팅 방식으로 결과를 출력하세요.
#
#
#
# C = 20
#
# F = cel * 9/5 + 32
#
# 출력 예시 : 섭씨 20도는 화씨 68.00도입니다.

# %%
c = 20

# %% [markdown]
# Q2. 운전 중인 자동차의 속도와 제한 속도를 입력받아, 과속 여부를 판단하는 문장을 출력하세요.
#
# curren = 85
#
# limit = 60
#
# 출력 예시 : "현재 속도는 85km/h로, 제한 속도 60km/h를 초과했습니다!"

# %%
current = 85
limit = 60

# %%
print(f'현재 속도는 {current}입니다.')
# Out:
# 현재 속도는 85입니다.

# %% [markdown]
# ## 4. 불형(Boolean)
#
# 불형(`bool`)은 논리값인 참(True)과 거짓(False)
# 주로 조건문에서 사용됨

# %%
student = True
teacher = False

# %% [markdown]
# ### 비교연산자

# %%
A = 3
B = 5
C = 8

# %%
# Q1. 나이가 18세 이상인지 확인하는 코드를 작성하세요
age = 20
age >= 18
# Out:
# True

# %%
# Q2. 숫자 x가 10 이상 20 이하인지 확인하는 코드
x = 15

10 <= x <=20
# Out:
# True

# %% [markdown]
# ### 논리연산자

# %%
x = 10
result = x % 2 == 0
result
# Out:
# True

# %%
student = True
teacher = False

# %% [markdown]
# Q1. 사용자에게 입력 받은 숫자 'x'의 값이 짝수인지 확인하여 결과를 출력해주는 연산을 만들어보세요

# %% [markdown]
# Q2. 사용자에게 입력 받은 숫자 'x'의 값이 0 이상 100 이하의 범위에 있는지 결과를 출력해주는 연산을 만들어보세요

# %%
0 <= x <= 100
# Out:
# True

# %% [markdown]
# ## 🌼마무리 문제
#
# 아래 문제들을 풀어보세요!
#
# Q1. 사용자로부터 이름과 나이를 `입력받아`, "안녕하세요, '이름'님. 당신은 '나이'세 이시군요!"라고 출력하는 코드를 작성해보세요

# %%
Name='송태희'
age='37'

print("안녕하세요, 'Name'님. 당신은'age'세 이시군요!")
# Out:
# 안녕하세요, 'Name'님. 당신은'age'세 이시군요!

# %% [markdown]
# Q2. BMI(체질량지수)를 계산하는 프로그램을 작성하세요.
# 사용자로부터 키(m)와 체중(kg)을 `입력받아` 계산 후 출력하세요.
# `*BMI계산법 : 체중(kg) / (키(m) x 키(m))`
