# %%
<doctype html>
<html lang="en">
 <head>
  <meta charset = "UTF-8" />
  <meta name= "viewport" content = "width = device - width, initial-scale = 1.0" />
  <title>
  </head>
  <body>
  </body>
  <html/>sß
# Out:
#   Cell In[18], line 1
#     <doctype html>
#     ^
# SyntaxError: invalid syntax
