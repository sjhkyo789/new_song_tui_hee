# %%
<!DOCTYPE html>
<html lang="ko">
  <head>
    <meta charset="utf-8">
    <title>목록 만들기</title>
  </head>
<body>
  <h1> 사랑스러운 반려동물</h1>
# Out:
#   Cell In[5], line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax
