# %%
CREATE TABLE users (
    user_id INTEGER PRIMARY KEY AUTO_INCREMENT,
    Username TEXT NOT NULL,
    email TEXT NOT NUL

);
    INSERT INTO users (Username, email)
    VALUES('alice', 'alice@abc.com'),
           (bruno, bruno@abc.com);


UPDATE users
SET username = 'caroline'Arithm
WHERE user_id = 2
# Out:
#   Cell In[2], line 1
#     CREATE TABLE users (
#            ^
# SyntaxError: invalid syntax
